# %% [markdown]
# [Home](Home.ipynb)
# # Youtube Gallery
#
# Your curated videos will not show up as actually viewable on Github, although the URL will be visible.
#
# To see a Github or other public Notebook through a view that renders Youtubes, try [nbviewer](https://nbviewer.jupyter.org/).

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("D1nw1PH4wjs")
